# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
# pd.set_option('max_columns', 200)

# %%
datay = pd.read_csv('/kaggle/input/walmart-sales/Walmart_sales.csv')

# %%
datay.shape
# Out:
# (6435, 8)

# %%
datay.head(20)
# Out:
#     Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0       1  05-02-2010    1643690.90             0        42.31       2.572
# 1       1  12-02-2010    1641957.44             1        38.51       2.548
# 2       1  19-02-2010    1611968.17             0        39.93       2.514
# 3       1  26-02-2010    1409727.59             0        46.63       2.561
# 4       1  05-03-2010    1554806.68             0        46.50       2.625
# 5       1  12-03-2010    1439541.59             0        57.79       2.667
# 6       1  19-03-2010    1472515.79             0        54.58       2.720
# 7       1  26-03-2010    1404429.92             0        51.45       2.732
# 8       1  02-04-2010    1594968.28             0        62.27       2.719
# 9       1  09-04-2010    1545418.53             0        65.86       2.770
# 10      1  16-04-2010    1466058.28             0        66.32       2.808
# ...

# %%
datay.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
datay.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
datay.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
datay
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
datay.isna().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
datay['Temperature'].head(10).plot(kind='bar', title = 'Temperature')
# Out:
# <Axes: title={'center': 'Temperature'}>

# %%
datay['Weekly_Sales'].plot(kind='hist', bins=20, title = 'Walmart Weekly Sales')
# Out:
# <Axes: title={'center': 'Walmart Weekly Sales'}, ylabel='Frequency'>

# %%
datay.plot(kind = 'scatter', x='Weekly_Sales', y='Unemployment', title='Weekly Sales vs Unemployment')
# Out:
# <Axes: title={'center': 'Weekly Sales vs Unemployment'}, xlabel='Weekly_Sales', ylabel='Unemployment'>

# %%
datay.plot(kind = 'scatter', x='Temperature', y='Fuel_Price', title='Temperature vs Fuel Price')
plt.show()

# %%
sns.scatterplot(x='Temperature', y='Fuel_Price', data = datay)
# Out:
# <Axes: xlabel='Temperature', ylabel='Fuel_Price'>

# %%
sns.pairplot(datay, vars= ['Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI','Unemployment'])
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.scatterplot(x='Date', y='Fuel_Price', data = datay)
plt.show()

# %% [markdown]
# How were the fuel prices acting as time passed?
